# %%
import pandas as pd

# %%
features=pd.read_csv("MPD_audio_0_99.csv")

# %%
features.head()
# Out:
#                              Unnamed: 0  danceability  energy  key  loudness  \
# 0  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI         0.904   0.813    4    -7.105
# 1  spotify:track:6I9VzXrHxO9rA9A5euc8Ak         0.774   0.838    5    -3.914
# 2  spotify:track:0WqIKmW4BTrj3eJFmnCKMv         0.664   0.758    2    -6.583
# 3  spotify:track:1AWQoqb9bSvzTjaLralEkT         0.891   0.714    4    -6.055
# 4  spotify:track:1lzr43nnXAijIGYnCT8M8H         0.853   0.606    0    -4.596
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     0       0.1210       0.03110          0.006970    0.0471    0.810
# 1     0       0.1140       0.02490          0.025000    0.2420    0.924
# 2     0       0.2100       0.00238          0.000000    0.0598    0.701
# 3     0       0.1400       0.20200          0.000234    0.0521    0.818
# 4     1       0.0713       0.05610          0.000000    0.3130    0.654
#
#      tempo
# 0  125.461
# 1  143.040
# 2   99.259
# 3  100.972
# ...

# %%
features=features.rename(columns={'Unnamed: 0':'track_uri'})

# %%
songs=pd.read_csv("test0-99.csv")

# %%
songs.head()
# Out:
#    pid  pos        artist_name                             track_uri  \
# 0    0    0      Missy Elliott  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1    0    1     Britney Spears  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2    0    2            Beyoncé  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3    0    3  Justin Timberlake  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4    0    4             Shaggy  spotify:track:1lzr43nnXAijIGYnCT8M8H
#
#                               artist_uri  \
# 0  spotify:artist:2wIVse2owClT7go1WT98tk
# 1  spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 2  spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 3  spotify:artist:31TPClRtHm23RisEBtV3X7
# 4  spotify:artist:5EvFsr3kj42KNv97ZEnqij
#
#                                    track_name  \
# 0  Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                       Toxic
# 2                               Crazy In Love
# 3                              Rock Your Body
# 4                                It Wasn't Me
#
# ...

# %%
features.columns
# Out:
# Index(['track_uri', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo'],
#       dtype='object')

# %%
songs_info=songs[['track_uri','track_name','artist_name']]

# %%
songs_info.head()
# Out:
#                               track_uri  \
# 0  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4  spotify:track:1lzr43nnXAijIGYnCT8M8H
#
#                                    track_name        artist_name
# 0  Lose Control (feat. Ciara & Fat Man Scoop)      Missy Elliott
# 1                                       Toxic     Britney Spears
# 2                               Crazy In Love            Beyoncé
# 3                              Rock Your Body  Justin Timberlake
# 4                                It Wasn't Me             Shaggy

# %%
merge=pd.merge(features, songs_info, on='track_uri')

# %%
merge.shape
# Out:
# (6677779, 14)

# %%
songs.shape
# Out:
# (6677800, 9)

# %%
merge.head()
# Out:
#                               track_uri  danceability  energy  key  loudness  \
# 0  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI         0.904   0.813    4    -7.105
# 1  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI         0.904   0.813    4    -7.105
# 2  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI         0.904   0.813    4    -7.105
# 3  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI         0.904   0.813    4    -7.105
# 4  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI         0.904   0.813    4    -7.105
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     0        0.121        0.0311           0.00697    0.0471     0.81
# 1     0        0.121        0.0311           0.00697    0.0471     0.81
# 2     0        0.121        0.0311           0.00697    0.0471     0.81
# 3     0        0.121        0.0311           0.00697    0.0471     0.81
# 4     0        0.121        0.0311           0.00697    0.0471     0.81
#
#      tempo                                  track_name    artist_name
# ...

# %%
features.head()
# Out:
#                               track_uri  danceability  energy  key  loudness  \
# 0  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI         0.904   0.813    4    -7.105
# 1  spotify:track:6I9VzXrHxO9rA9A5euc8Ak         0.774   0.838    5    -3.914
# 2  spotify:track:0WqIKmW4BTrj3eJFmnCKMv         0.664   0.758    2    -6.583
# 3  spotify:track:1AWQoqb9bSvzTjaLralEkT         0.891   0.714    4    -6.055
# 4  spotify:track:1lzr43nnXAijIGYnCT8M8H         0.853   0.606    0    -4.596
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     0       0.1210       0.03110          0.006970    0.0471    0.810
# 1     0       0.1140       0.02490          0.025000    0.2420    0.924
# 2     0       0.2100       0.00238          0.000000    0.0598    0.701
# 3     0       0.1400       0.20200          0.000234    0.0521    0.818
# 4     1       0.0713       0.05610          0.000000    0.3130    0.654
#
#      tempo
# 0  125.461
# 1  143.040
# 2   99.259
# 3  100.972
# ...

# %%
features.shape
# Out:
# (681787, 12)

# %%
merge2=merge.drop_duplicates()

# %%
merge2.shape
# Out:
# (681787, 14)

# %%
merge2.head()
# Out:
#                                  track_uri  danceability  energy  key  \
# 0     spotify:track:0UaMYEvWZi0ZqiDOoHU3YI         0.904   0.813    4
# 690   spotify:track:6I9VzXrHxO9rA9A5euc8Ak         0.774   0.838    5
# 1998  spotify:track:0WqIKmW4BTrj3eJFmnCKMv         0.664   0.758    2
# 3671  spotify:track:1AWQoqb9bSvzTjaLralEkT         0.891   0.714    4
# 4582  spotify:track:1lzr43nnXAijIGYnCT8M8H         0.853   0.606    0
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0       -7.105     0       0.1210       0.03110          0.006970    0.0471
# 690     -3.914     0       0.1140       0.02490          0.025000    0.2420
# 1998    -6.583     0       0.2100       0.00238          0.000000    0.0598
# 3671    -6.055     0       0.1400       0.20200          0.000234    0.0521
# 4582    -4.596     1       0.0713       0.05610          0.000000    0.3130
#
#       valence    tempo                                  track_name  \
# ...

# %%
merge2=merge2.reset_index(drop=True)

# %%
merge2.head()
# Out:
#                               track_uri  danceability  energy  key  loudness  \
# 0  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI         0.904   0.813    4    -7.105
# 1  spotify:track:6I9VzXrHxO9rA9A5euc8Ak         0.774   0.838    5    -3.914
# 2  spotify:track:0WqIKmW4BTrj3eJFmnCKMv         0.664   0.758    2    -6.583
# 3  spotify:track:1AWQoqb9bSvzTjaLralEkT         0.891   0.714    4    -6.055
# 4  spotify:track:1lzr43nnXAijIGYnCT8M8H         0.853   0.606    0    -4.596
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     0       0.1210       0.03110          0.006970    0.0471    0.810
# 1     0       0.1140       0.02490          0.025000    0.2420    0.924
# 2     0       0.2100       0.00238          0.000000    0.0598    0.701
# 3     0       0.1400       0.20200          0.000234    0.0521    0.818
# 4     1       0.0713       0.05610          0.000000    0.3130    0.654
#
# ...

# %%
merge2.to_csv("tracks_features_info.csv")
